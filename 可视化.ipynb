# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HR.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
df=df.dropna(axis=0,how='any')
df=df[df.last_evaluation<=1][df.salary!='nme'][df.department!='sale']
# Out:
# C:\Users\ni\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
x=np.arange(len(df['salary'].value_counts()))
y=df['salary'].value_counts()

# %%
x = np.arange(len(df['salary'].value_counts()))
y = df['salary'].value_counts()

# %%
sns.set_palette(sns.color_palette(['#FF4040']))
sns.set_style(style='whitegrid')
sns.set_context(context='talk')
plt.title('salary')
plt.xlabel('salary')
plt.ylabel('number')
plt.xticks(np.arange(len(df['salary'].value_counts())),df['salary'].value_counts().index)
plt.axis([0,4,0,8000])
for xx,yy in zip(x,y):
    plt.text(xx+0.5,yy,yy,ha='center',va='bottom',color='red')
plt.bar(x+0.5,y,width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
sns.set_palette(sns.color_palette(['#FF4040']))
sns.set_style(style='whitegrid')
sns.set_context(context='talk')
plt.title('salary')
plt.xlabel('salary')
plt.ylabel('number')
plt.xticks(np.arange(len(df['salary'].value_counts())),df['salary'].value_counts().index)
plt.axis([0,4,0,8000])
for xx,yy in zip(x,y):
    plt.text(xx+0.5,yy,yy,ha='center',va='bottom',color='red')
plt.bar(x+0.5,y,width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
sns.countplot(x='salary',hue='department',data=df)

# %%
sns.countplot(x='salary',hue='department',data=df)

# %%
f=plt.figure(figsize=(18,6))
f.add_subplot(1,3,1)
sns.distplot(df['satisfaction_level'],bins=10)
f.add_subplot(1,3,2)

# %%
f=plt.figure(figsize=(18,6))
f.add_subplot(1,3,1)
sns.distplot(df['satisfaction_level'],bins=10)
f.add_subplot(1,3,2)
sns.distplot(df['last_evaluation'],bins=10)
f.add_subplot(1,3,3)
sns.distplot(df['average_monthly_hours'],bins=10)

# %%
sns.boxplot(x=df['time_spend_company'],saturation=1,whis=2)

# %%
d=plt.figure()
sns.boxplot(x=df['time_spend_company'],saturation=1,whis=3)

# %%
sub_df=df.groupby('time_spend_company').mean()
sns.pointplot(sub_df.index,sub_df['left'])

# %%
sns.pointplot(x='time_spend_company',y='left',data=df)

# %%
sub_df=df.groupby('time_spend_company').mean()
sns.pointplot(sub_df.index,sub_df['left'])

# %%
sns.pointplot(x='time_spend_company',y='left',data=df)

# %%
label=df['department'].value_counts().index
explode=[0.1 if x=='sales' else 0 for x in label]
plt.pie[df['department'].value_counts(normalize=True),colors=sns.color_palette("RdBu", n_colors=7),labels=label,expl]

# %%
plt.figure(figsize=(10,8))
label=df['department'].value_counts().index
explode=[0.1  if x=='sales' else 0 for x in label ]
plt.pie(df['department'].value_counts(normalize=True),colors=sns.color_palette("RdBu", n_colors=7),labels=label,explode=explode,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x5bc3896f60>,
# ...
#  [Text(0.776414318993718, 0.9149758495509712, 'sales'),
#   Text(-0.7361690652250792, 0.8173463815333333, 'technical'),
#   Text(-1.078295473144608, -0.21743705433031926, 'support'),
#   Text(-0.6639038295740627, -0.8770585528212437, 'IT'),
#   Text(-0.220711694218203, -1.0776299680480914, 'product_mng'),
#   Text(0.1824348726672272, -1.0847661117655236, 'marketing'),
#   Text(0.5381184913305728, -0.9593896441426228, 'RandD'),
#   Text(0.8166516060190341, -0.7369397223562675, 'accounting'),
#   Text(1.004980939261518, -0.4472284782088872, 'hr'),
#   Text(1.090437030943069, -0.1447310662852455, 'management')],
#  [Text(0.45290835274633545, 0.5337359122380665, '27.60%'),
#   Text(-0.40154676285004315, 0.44582529901818174, '18.13%'),
#   Text(-0.5881611671697861, -0.11860202963471958, '14.86%'),
#   Text(-0.36212936158585235, -0.4783955742661329, '8.18%'),
#   Text(-0.12038819684629253, -0.587798164389868, '6.01%'),
# ...

# %%
plt.figure(figsize=(10,8))
label=df['salary'].value_counts().index
explode=[0.1  if x=='high' else 0 for x in label ]
plt.pie(df['salary'].value_counts(normalize=True),colors=sns.color_palette("RdBu", n_colors=7),labels=label,explode=explode,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x5bc3ab4240>,
# ...
#  [Text(0.04226778373338524, 1.0991876247748915, 'low'),
#   Text(-0.32247422223497674, -1.051670279124568, 'medium'),
#   Text(1.1599469946307854, -0.307445880842481, 'high')],
#  [Text(0.02305515476366467, 0.5995568862408499, '48.78%'),
#   Text(-0.1758950303099873, -0.5736383340679462, '42.98%'),
#   Text(0.676635746867958, -0.17934343049144724, '8.25%')])
